# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_decision_regions

# %%
df=pd.read_csv("placement.csv")

# %%
df.head()
# Out:
#    CGPA  Score  Placed
# 0   6.5     65       0
# 1   7.0     70       1
# 2   8.2     80       1
# 3   5.8     55       0
# 4   6.9     68       0

# %%
df.isnull().sum()
# Out:
# CGPA      0
# Score     0
# Placed    0
# dtype: int64

# %%
sns.kdeplot(data=df["CGPA"])
# Out:
# <Axes: xlabel='CGPA', ylabel='Density'>

# %%
sns.kdeplot(data=df["Score"])
# Out:
# <Axes: xlabel='Score', ylabel='Density'>

# %%
sns.scatterplot(x="CGPA",y="Score",data=df,hue="Placed")
# Out:
# <Axes: xlabel='CGPA', ylabel='Score'>

# %%
x=df.iloc[:,:-1]
y=df["Placed"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB

# %% [markdown]
# ## Gaussian Naive Bayes

# %%
gnb=GaussianNB()

# %%
gnb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
gnb.score(x_test,y_test)*100,gnb.score(x_train,y_train)*100
# Out:
# (100.0, 97.14285714285714)

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=gnb)
# Out:
# C:\Users\Ankita Ghavate\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
gnb.predict([[5.8,55]])
# Out:
# C:\Users\Ankita Ghavate\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %% [markdown]
# ## MultiNomial Naive Bayes

# %%
mnb=MultinomialNB()

# %%
mnb.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
mnb.score(x_test,y_test)*100
# Out:
# 53.333333333333336

# %%
mnb.score(x_train,y_train)*100
# Out:
# 60.0

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=mnb)
# Out:
# C:\Users\Ankita Ghavate\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MultinomialNB was fitted with feature names
#   warnings.warn(
# <Axes: >

# %% [markdown]
# ## Bernoulli Naive Bayes

# %%
bnb=BernoulliNB()

# %%
bnb.fit(x_train,y_train)
# Out:
# BernoulliNB()

# %%
bnb.score(x_test,y_test)*100
# Out:
# 53.333333333333336

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=bnb)
# Out:
# C:\Users\Ankita Ghavate\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but BernoulliNB was fitted with feature names
#   warnings.warn(
# <Axes: >
